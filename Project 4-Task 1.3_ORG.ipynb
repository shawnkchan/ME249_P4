# %%
from scipy import stats
import matplotlib.pyplot as plt

'''
Function that takes in two dataframe columns and plots a log-log graph
Follows standardised formatting
@input recorded: dataframe column of recorded data
@input predicted: dataframe column of the predicted value
@input xmin: lower bound of graph's x axis
@input xmax: upper bound of graph's x axis
@input ymin: lower bound of graph's y axis
@input ymax: upper bound of graph's y axis
@input xTitle: title for x axis
@input yTitle: title for y axis
@output log log graph of the preducted values against recorded values
'''

def logLogPlotter(recorded, predicted, xmin, xmax, ymin, ymax, xTitle, yTitle, unit):
    x = recorded
    y = predicted

    coefficients = np.polyfit(np.log(x), np.log(y), 1)
    line_function = np.poly1d(coefficients)

    # Create a range for predicted values for the fit line
    x_vals = np.linspace(min(x), max(y), 400)
    y_vals = np.exp(line_function(np.log(x_vals)))

    #calculate similarity measures
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

    #best fit line and y = x line
    plt.scatter(x, y, c='red', marker='x')
    plt.plot(x_vals, y_vals, color='red', label=f'Fit: y = {coefficients[0]:.2f}x + {coefficients[1]:.2f}')
    plt.axline((0, 0), (1,1),color='black',linestyle='--', label=f'y=x, R^2 = {r_value ** 2}',)

    #visuals
    font_family = 'Times New Roman'
    title_font_size=17
    label_font_size=15
    legend_tick_font_size=12

    plt.title(f'Predicted {yTitle} against Recorded {xTitle}', fontsize=title_font_size, fontfamily=font_family)
    plt.xlabel(f'Recorded {xTitle} ({unit})', fontsize=label_font_size, fontfamily=font_family)
    plt.ylabel(f'Predicted {yTitle} ({unit})', fontsize=label_font_size, fontfamily=font_family)

    plt.legend(fontsize = legend_tick_font_size)
    plt.loglog()
    plt.xlim(xmax=xmax, xmin=xmin)
    plt.ylim(ymax=ymax, ymin=ymin)

    plt.show()

# %%
'''>>>>> start CodeP4.1F23
V.P. Carey ME249, Fall 2023
Keras Neural Network Modeling '''
#import useful packages
import keras
import pandas as pd
from keras.models import Sequential
import numpy as np
import keras.backend as kb
import tensorflow as tf
#the following 2 lines are only needed for Mac OS machines
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# define meadian values of input variables - add your values here

import statistics
import numpy
xdata = []
ydata = []
#xdata.append([ Di(m), qoflux (kW/m^2), exit quality, max wall temperature (deg C)])
xdata.append([0.008, 550, 0.525, 306.7])
xdata.append([0.008, 650, 0.525, 298.5])
xdata.append([0.008, 750, 0.525, 294.2])
xdata.append([0.008, 850, 0.525, 290.2])
xdata.append([0.008, 950, 0.524, 286.9])
xdata.append([0.008, 1050, 0.524, 284.1])
xdata.append([0.008, 1150, 0.525, 281.7])
xdata.append([0.008, 850, 0.524, 290.31])
xdata.append([0.008, 550, 0.734, 307.9])
xdata.append([0.008, 750, 0.735, 295.5])
xdata.append([0.008, 950, 0.735, 287.8])
xdata.append([0.008, 1050, 0.735, 285.0])
xdata.append([0.008, 1150, 0.735, 282.5])
xdata.append([0.008, 850, 0.734, 291.3])
xdata.append([0.008, 550, 0.945, 308.6])
xdata.append([0.008, 750, 0.945, 296.2])
xdata.append([0.008, 950, 0.945, 288.5])
xdata.append([0.008, 1150, 0.945, 283.1])
xdata.append([0.008, 850, 0.945, 291.9])
xdata.append([0.011, 550, 0.525, 328.0])
xdata.append([0.011, 750, 0.525, 311.2])
xdata.append([0.011, 950, 0.525, 300.8])
xdata.append([0.011, 1150, 0.525, 293.6])
xdata.append([0.011, 850, 0.525, 305.5])
xdata.append([0.011, 550, 0.735, 329.6])
xdata.append([0.011, 750, 0.735, 312.6])
xdata.append([0.011, 950, 0.735, 302.0])
xdata.append([0.011, 1050, 0.735, 299.4])
xdata.append([0.011, 1150, 0.735, 294.8])
xdata.append([0.011, 850, 0.735, 306.8])
xdata.append([0.011, 550, 0.945, 330.7])
xdata.append([0.011, 750, 0.945, 313.6])
xdata.append([0.011, 950, 0.944, 302.9])
xdata.append([0.011, 1150, 0.945, 295.6])
xdata.append([0.011, 850, 0.944, 307.7])
xdata.append([0.011, 700, 0.734, 324.7])
xdata.append([0.013, 550, 0.525, 342.2])
xdata.append([0.013, 750, 0.524, 322.3])
xdata.append([0.013, 950, 0.524, 310.0])
xdata.append([0.013, 1150, 0.525, 301.6])
xdata.append([0.013, 850, 0.524, 315.5])
xdata.append([0.013, 550, 0.734, 344.1])
xdata.append([0.013, 750, 0.735, 324.0])
xdata.append([0.013, 950, 0.735, 311.5])
xdata.append([0.013, 1050, 0.735, 306.3])
xdata.append([0.013, 1150, 0.735, 302.9])
xdata.append([0.013, 850, 0.734, 317.1])
xdata.append([0.013, 550, 0.945, 345.3])
xdata.append([0.013, 750, 0.944, 325.1])
xdata.append([0.013, 950, 0.944, 312.5])
xdata.append([0.013, 1150, 0.945, 303.9])
xdata.append([0.013, 850, 0.945, 318.2])

#data.append([mdot (kg/s)])
ydata.append([0.06157])
ydata.append([0.07269])
ydata.append([0.08396])
ydata.append([0.09347])
ydata.append([0.10635])
ydata.append([0.11521])
ydata.append([0.1287])
ydata.append([0.09516])
ydata.append([0.04398])
ydata.append([0.05997])
ydata.append([0.07596])
ydata.append([0.08343])
ydata.append([0.0919])
ydata.append([0.06797])
ydata.append([0.0342])
ydata.append([0.04664])
ydata.append([0.05908])
ydata.append([0.0715])
ydata.append([0.05286])
ydata.append([0.0846])
ydata.append([0.1154])
ydata.append([0.1462])
ydata.append([0.177])
ydata.append([0.1308])
ydata.append([0.06047])
ydata.append([0.08246])
ydata.append([0.1044])
ydata.append([0.1134])
ydata.append([0.1264])
ydata.append([0.0934])
ydata.append([0.047])
ydata.append([0.06413])
ydata.append([0.08124])
ydata.append([0.09834])
ydata.append([0.072691])
ydata.append([0.087196])
ydata.append([0.10005])
ydata.append([0.13644])
ydata.append([0.17282])
ydata.append([0.2092])
ydata.append([0.15463])
ydata.append([0.07147])
ydata.append([0.09745])
ydata.append([0.12344])
ydata.append([0.13302])
ydata.append([0.1494])
ydata.append([0.11045])
ydata.append([0.05558])
ydata.append([0.0758])
ydata.append([0.09601])
ydata.append([0.1162])
ydata.append([0.0859])
xarray= numpy.array(xdata)
yarray= numpy.array(ydata)
# print (xdata)
# print (xarray)
# print (ydata)
# print (yarray)
x_original = np.array(xdata)
y_original = np.array(ydata)

#convert to:
# median values of output variables
ND=len(xarray)
Diall = [row[0] for row in xdata]
Dimed=statistics.median(Diall)
q0all = [row[1] for row in xdata]
q0med=statistics.median(q0all)
xeall = [row[2] for row in xdata]
xemed=statistics.median(xeall)
Twall = [row[3] for row in xdata]
Twmed=statistics.median(Twall)

mall = [row[0] for row in ydata]
mmed=statistics.median(mall)

xdata = []
ydata = []
for i in range(ND):
    xdata.append([xarray[i,0]/Dimed,xarray[i,1]/q0med,xarray[i,2]/xemed,xarray[i,3]/Twmed])
    ydata.append([yarray[i,0]/mmed])

xarray= np.array(xdata)
yarray= np.array(ydata)

#print (yarray)

data_inputs = np.array(xdata)
data_outputs = np.array(ydata)

# %%
xdata_df = pd.DataFrame(x_original, columns=['Di', 'qoflux', 'xe', 'mdot'])
ydata_df = pd.DataFrame(y_original, columns=['mdot'])

# %%
xdata_normalized = xdata_df.divide(xdata_df.median())
ydata_normalized = ydata_df.divide(ydata_df.median())

# %%
from sklearn.model_selection import train_test_split
training_input,validation_input,training_output,validation_output = train_test_split(xarray,
yarray, test_size=0.25, random_state=13)
# print to check the shape of training and validation set
training_input= np.array(training_input)#[:,[1,2,3]])
training_output= np.array(training_output)
validation_input= np.array(validation_input)#[:,[1,2,3]])
validation_output= np.array(validation_output)

print(validation_input)

xarray=training_input
yarray=training_output
# Out:
# [[1.18181818 0.88235294 1.         1.06334099]
#  [0.72727273 1.11764706 0.71292517 0.94158188]
#  [1.         0.88235294 0.71428571 1.02133246]
#  [1.18181818 1.35294118 1.28571429 0.99737447]
#  [0.72727273 0.64705882 0.71428571 1.00656383]
#  [0.72727273 0.64705882 1.28571429 1.01279947]
#  [1.18181818 1.         0.71292517 1.0354447 ]
#  [1.         1.         1.         1.00689202]
#  [1.18181818 1.35294118 1.         0.99409255]
#  [0.72727273 1.35294118 0.71428571 0.92451592]
#  [1.         1.35294118 1.         0.96750903]
#  [1.         1.         0.71428571 1.00262553]
#  [1.18181818 0.64705882 1.28571429 1.13324582]]

# %%
x_train = pd.DataFrame(training_input, columns=['Di', 'qoflux', 'xe', 'mdot'])
x_validate = pd.DataFrame(validation_input,columns=['Di', 'qoflux', 'xe', 'mdot'])

y_train = pd.DataFrame(training_output, columns=['mdot'])
y_validate = pd.DataFrame(validation_output, columns=['mdot'])

# %%
# define neural network model
#As seen below, we have created four dense layers.
#A dense layer is a layer in neural network that’s fully connected.
#In other words, all the neurons in one layer are connected to all other neurons in the next layer.
#In the first layer, we need to provide the input shape, which is 1 in our case.
#The activation function we have chosen is elu, which stands for exponential linear unit. .
from keras import backend as K
#initialize weights with values between -0.2 and 0.5
initializer = keras.initializers.RandomUniform(minval= -0.2, maxval=0.5)
model = keras.Sequential([
keras.layers.Dense(6, activation=K.elu, input_shape=[4], kernel_initializer=initializer),
keras.layers.Dense(8, activation=K.elu, kernel_initializer=initializer),
keras.layers.Dense(12, activation=K.elu, kernel_initializer=initializer),
keras.layers.Dense(16, activation=K.elu, kernel_initializer=initializer),
keras.layers.Dense(8, activation=K.elu, kernel_initializer=initializer),
keras.layers.Dense(1, kernel_initializer=initializer)
])

# %%
#We’re using RMSprop as our optimizer here. RMSprop stands for Root Mean Square Propagation.
#It’s one of the most popular gradient descent optimization algorithms for deep learning networks.
#RMSprop is an optimizer that’s reliable and fast.
#We’re compiling the mode using the model.compile function. The loss function used here
#is mean squared error. After the compilation of the model, we’ll use the fit method with ~500 epochs.
#Number of epochs can be varied.
#from tf.keras import optimizers
rms = keras.optimizers.RMSprop(0.01)
model.compile(loss='mean_absolute_error',optimizer=rms)

# %%
#After the compilation of the model, we’ll use the fit method with 500 epochs.
#I started with epochs value of 100 and then tested the model after training.
#The prediction was not that good. Then I modified the number of epochs to 200 and tested the model again.
#Accuracy had improved slightly, but figured I’d give it one more try. Finally, at 500 epochs
#I found acceptable prediction accuracy.
#The fit method takes three parameters; namely, x, y, and number of epochs.
#During model training, if all the batches of data are seen by the model once,
#we say that one epoch has been completed.
# Add an early stopping callback
es = keras.callbacks.EarlyStopping(
monitor='loss',
mode='min',
patience = 90,
restore_best_weights = True,
verbose=1)
# Add a checkpoint where loss is minimum, and save that model
mc = keras.callbacks.ModelCheckpoint('best_model.SB', monitor='loss',
mode='min', verbose=1, save_best_only=True)
historyData = model.fit(xarray,yarray,epochs=800,callbacks=[es])
loss_hist = historyData.history['loss']
#The above line will return a dictionary, access it's info like this:
best_epoch = np.argmin(historyData.history['loss']) + 1
print ('best epoch = ', best_epoch)
print('smallest loss =', np.min(loss_hist))
model.save('./best_model')
# Out:
# Epoch 1/800
# 39/39 [==============================] - 1s 18ms/step - loss: 1.0853
# Epoch 2/800
# 39/39 [==============================] - 0s 303us/step - loss: 0.3059
# Epoch 3/800
# 39/39 [==============================] - 0s 661us/step - loss: 0.3085
# Epoch 4/800
# 39/39 [==============================] - 0s 530us/step - loss: 0.4283
# Epoch 5/800
# 39/39 [==============================] - 0s 302us/step - loss: 0.3788
# Epoch 6/800
# 39/39 [==============================] - 0s 911us/step - loss: 0.3445
# Epoch 7/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3175
# Epoch 8/800
# 39/39 [==============================] - 0s 393us/step - loss: 0.5141
# Epoch 9/800
# 39/39 [==============================] - 0s 479us/step - loss: 0.2928
# Epoch 10/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3331
# Epoch 11/800
# 39/39 [==============================] - 0s 461us/step - loss: 0.4212
# Epoch 12/800
# 39/39 [==============================] - 0s 343us/step - loss: 0.4205
# Epoch 13/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3581
# Epoch 14/800
# 39/39 [==============================] - 0s 886us/step - loss: 0.3091
# Epoch 15/800
# 39/39 [==============================] - 0s 668us/step - loss: 0.4737
# Epoch 16/800
# 39/39 [==============================] - 0s 818us/step - loss: 0.3117
# Epoch 17/800
# 39/39 [==============================] - 0s 695us/step - loss: 0.4342
# Epoch 18/800
# 39/39 [==============================] - 0s 930us/step - loss: 0.3678
# Epoch 19/800
# 39/39 [==============================] - 0s 523us/step - loss: 0.3738
# Epoch 20/800
# 39/39 [==============================] - 0s 315us/step - loss: 0.2713
# Epoch 21/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.2805
# Epoch 22/800
# 39/39 [==============================] - 0s 375us/step - loss: 0.3238
# Epoch 23/800
# 39/39 [==============================] - 0s 576us/step - loss: 0.4193
# Epoch 24/800
# 39/39 [==============================] - 0s 275us/step - loss: 0.3510
# Epoch 25/800
# 39/39 [==============================] - 0s 295us/step - loss: 0.3822
# Epoch 26/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.2479
# Epoch 27/800
# 39/39 [==============================] - 0s 370us/step - loss: 0.3016
# Epoch 28/800
# 39/39 [==============================] - 0s 352us/step - loss: 0.4190
# Epoch 29/800
# 39/39 [==============================] - 0s 415us/step - loss: 0.3073
# Epoch 30/800
# 39/39 [==============================] - 0s 255us/step - loss: 0.2718
# Epoch 31/800
# 39/39 [==============================] - 0s 569us/step - loss: 0.2980
# Epoch 32/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.2412
# Epoch 33/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.2225
# Epoch 34/800
# 39/39 [==============================] - 0s 810us/step - loss: 0.2354
# Epoch 35/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5175
# Epoch 36/800
# 39/39 [==============================] - 0s 744us/step - loss: 0.2133
# Epoch 37/800
# 39/39 [==============================] - 0s 883us/step - loss: 0.2209
# Epoch 38/800
# 39/39 [==============================] - 0s 395us/step - loss: 0.2559
# Epoch 39/800
# 39/39 [==============================] - 0s 405us/step - loss: 0.2782
# Epoch 40/800
# 39/39 [==============================] - 0s 814us/step - loss: 0.2868
# Epoch 41/800
# 39/39 [==============================] - 0s 408us/step - loss: 0.2331
# Epoch 42/800
# 39/39 [==============================] - 0s 503us/step - loss: 0.2340
# Epoch 43/800
# 39/39 [==============================] - 0s 291us/step - loss: 0.2527
# Epoch 44/800
# 39/39 [==============================] - 0s 399us/step - loss: 0.3106
# Epoch 45/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1834
# Epoch 46/800
# 39/39 [==============================] - 0s 867us/step - loss: 0.1838
# Epoch 47/800
# 39/39 [==============================] - 0s 332us/step - loss: 0.3914
# Epoch 48/800
# 39/39 [==============================] - 0s 369us/step - loss: 0.4017
# Epoch 49/800
# 39/39 [==============================] - 0s 311us/step - loss: 0.2726
# Epoch 50/800
# 39/39 [==============================] - 0s 620us/step - loss: 0.1705
# Epoch 51/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.2995
# Epoch 52/800
# 39/39 [==============================] - 0s 307us/step - loss: 0.3283
# Epoch 53/800
# 39/39 [==============================] - 0s 583us/step - loss: 0.2702
# Epoch 54/800
# 39/39 [==============================] - 0s 662us/step - loss: 0.2518
# Epoch 55/800
# 39/39 [==============================] - 0s 311us/step - loss: 0.1603
# Epoch 56/800
# 39/39 [==============================] - 0s 686us/step - loss: 0.3398
# Epoch 57/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.2840
# Epoch 58/800
# 39/39 [==============================] - 0s 592us/step - loss: 0.3204
# Epoch 59/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1434
# Epoch 60/800
# 39/39 [==============================] - 0s 539us/step - loss: 0.2835
# Epoch 61/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.2662
# Epoch 62/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.2535
# Epoch 63/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1265
# Epoch 64/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1919
# Epoch 65/800
# 39/39 [==============================] - 0s 713us/step - loss: 0.1785
# Epoch 66/800
# 39/39 [==============================] - 0s 684us/step - loss: 0.2806
# Epoch 67/800
# 39/39 [==============================] - 0s 527us/step - loss: 0.1610
# Epoch 68/800
# 39/39 [==============================] - 0s 467us/step - loss: 0.2186
# Epoch 69/800
# 39/39 [==============================] - 0s 472us/step - loss: 0.2355
# Epoch 70/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.2802
# Epoch 71/800
# 39/39 [==============================] - 0s 361us/step - loss: 0.1336
# Epoch 72/800
# 39/39 [==============================] - 0s 270us/step - loss: 0.3960
# Epoch 73/800
# 39/39 [==============================] - 0s 250us/step - loss: 0.1646
# Epoch 74/800
# 39/39 [==============================] - 0s 180us/step - loss: 0.2399
# Epoch 75/800
# 39/39 [==============================] - 0s 284us/step - loss: 0.2606
# Epoch 76/800
# 39/39 [==============================] - 0s 347us/step - loss: 0.1864
# Epoch 77/800
# 39/39 [==============================] - 0s 432us/step - loss: 0.1376
# Epoch 78/800
# 39/39 [==============================] - 0s 892us/step - loss: 0.3358
# Epoch 79/800
# 39/39 [==============================] - 0s 490us/step - loss: 0.1949
# Epoch 80/800
# 39/39 [==============================] - 0s 418us/step - loss: 0.1846
# Epoch 81/800
# 39/39 [==============================] - 0s 408us/step - loss: 0.2428
# Epoch 82/800
# 39/39 [==============================] - 0s 726us/step - loss: 0.2590
# Epoch 83/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1497
# Epoch 84/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3287
# Epoch 85/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.2453
# Epoch 86/800
# 39/39 [==============================] - 0s 416us/step - loss: 0.1771
# Epoch 87/800
# 39/39 [==============================] - 0s 248us/step - loss: 0.1516
# Epoch 88/800
# 39/39 [==============================] - 0s 742us/step - loss: 0.2129
# Epoch 89/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1993
# Epoch 90/800
# 39/39 [==============================] - 0s 443us/step - loss: 0.2325
# Epoch 91/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.2267
# Epoch 92/800
# 39/39 [==============================] - 0s 323us/step - loss: 0.2213
# Epoch 93/800
# 39/39 [==============================] - 0s 521us/step - loss: 0.1926
# Epoch 94/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1664
# Epoch 95/800
# 39/39 [==============================] - 0s 519us/step - loss: 0.2173
# Epoch 96/800
# 39/39 [==============================] - 0s 590us/step - loss: 0.1813
# Epoch 97/800
# 39/39 [==============================] - 0s 462us/step - loss: 0.1311
# Epoch 98/800
# 39/39 [==============================] - 0s 373us/step - loss: 0.1831
# Epoch 99/800
# 39/39 [==============================] - 0s 379us/step - loss: 0.2027
# Epoch 100/800
# 39/39 [==============================] - 0s 300us/step - loss: 0.2560
# Epoch 101/800
# 39/39 [==============================] - 0s 864us/step - loss: 0.2561
# Epoch 102/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1949
# Epoch 103/800
# 39/39 [==============================] - 0s 306us/step - loss: 0.1283
# Epoch 104/800
# 39/39 [==============================] - 0s 304us/step - loss: 0.2603
# Epoch 105/800
# 39/39 [==============================] - 0s 781us/step - loss: 0.1782
# Epoch 106/800
# 39/39 [==============================] - 0s 723us/step - loss: 0.1452
# Epoch 107/800
# 39/39 [==============================] - 0s 415us/step - loss: 0.1491
# Epoch 108/800
# 39/39 [==============================] - 0s 772us/step - loss: 0.1936
# Epoch 109/800
# 39/39 [==============================] - 0s 642us/step - loss: 0.1319
# Epoch 110/800
# 39/39 [==============================] - 0s 551us/step - loss: 0.2194
# Epoch 111/800
# 39/39 [==============================] - 0s 410us/step - loss: 0.1894
# Epoch 112/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1847
# Epoch 113/800
# 39/39 [==============================] - 0s 693us/step - loss: 0.1740
# Epoch 114/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1839
# Epoch 115/800
# 39/39 [==============================] - 0s 714us/step - loss: 0.0947
# Epoch 116/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.2383
# Epoch 117/800
# 39/39 [==============================] - 0s 293us/step - loss: 0.1313
# Epoch 118/800
# 39/39 [==============================] - 0s 359us/step - loss: 0.2216
# Epoch 119/800
# 39/39 [==============================] - 0s 375us/step - loss: 0.1826
# Epoch 120/800
# 39/39 [==============================] - 0s 210us/step - loss: 0.2114
# Epoch 121/800
# 39/39 [==============================] - 0s 476us/step - loss: 0.2258
# Epoch 122/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1903
# Epoch 123/800
# 39/39 [==============================] - 0s 507us/step - loss: 0.2108
# Epoch 124/800
# 39/39 [==============================] - 0s 383us/step - loss: 0.1786
# Epoch 125/800
# 39/39 [==============================] - 0s 498us/step - loss: 0.1887
# Epoch 126/800
# 39/39 [==============================] - 0s 445us/step - loss: 0.1799
# Epoch 127/800
# 39/39 [==============================] - 0s 490us/step - loss: 0.1886
# Epoch 128/800
# 39/39 [==============================] - 0s 532us/step - loss: 0.1388
# Epoch 129/800
# 39/39 [==============================] - 0s 421us/step - loss: 0.1759
# Epoch 130/800
# 39/39 [==============================] - 0s 249us/step - loss: 0.1562
# Epoch 131/800
# 39/39 [==============================] - 0s 419us/step - loss: 0.1594
# Epoch 132/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1551
# Epoch 133/800
# 39/39 [==============================] - 0s 548us/step - loss: 0.1450
# Epoch 134/800
# 39/39 [==============================] - 0s 633us/step - loss: 0.1798
# Epoch 135/800
# 39/39 [==============================] - 0s 415us/step - loss: 0.1930
# Epoch 136/800
# 39/39 [==============================] - 0s 476us/step - loss: 0.1700
# Epoch 137/800
# 39/39 [==============================] - 0s 378us/step - loss: 0.1410
# Epoch 138/800
# 39/39 [==============================] - 0s 581us/step - loss: 0.1697
# Epoch 139/800
# 39/39 [==============================] - 0s 230us/step - loss: 0.1335
# Epoch 140/800
# 39/39 [==============================] - 0s 157us/step - loss: 0.1946
# Epoch 141/800
# 39/39 [==============================] - 0s 602us/step - loss: 0.2131
# Epoch 142/800
# 39/39 [==============================] - 0s 394us/step - loss: 0.1363
# Epoch 143/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1735
# Epoch 144/800
# 39/39 [==============================] - 0s 160us/step - loss: 0.1947
# Epoch 145/800
# 39/39 [==============================] - 0s 628us/step - loss: 0.2368
# Epoch 146/800
# 39/39 [==============================] - 0s 273us/step - loss: 0.1366
# Epoch 147/800
# 39/39 [==============================] - 0s 180us/step - loss: 0.1624
# Epoch 148/800
# 39/39 [==============================] - 0s 513us/step - loss: 0.1918
# Epoch 149/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1823
# Epoch 150/800
# 39/39 [==============================] - 0s 883us/step - loss: 0.1658
# Epoch 151/800
# 39/39 [==============================] - 0s 272us/step - loss: 0.1475
# Epoch 152/800
# 39/39 [==============================] - 0s 554us/step - loss: 0.1111
# Epoch 153/800
# 39/39 [==============================] - 0s 331us/step - loss: 0.1418
# Epoch 154/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1841
# Epoch 155/800
# 39/39 [==============================] - 0s 793us/step - loss: 0.1068
# Epoch 156/800
# 39/39 [==============================] - 0s 413us/step - loss: 0.0791
# Epoch 157/800
# 39/39 [==============================] - 0s 333us/step - loss: 0.2038
# Epoch 158/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0992
# Epoch 159/800
# 39/39 [==============================] - 0s 584us/step - loss: 0.0860
# Epoch 160/800
# 39/39 [==============================] - 0s 586us/step - loss: 0.2344
# Epoch 161/800
# 39/39 [==============================] - 0s 256us/step - loss: 0.1492
# Epoch 162/800
# 39/39 [==============================] - 0s 341us/step - loss: 0.1536
# Epoch 163/800
# 39/39 [==============================] - 0s 259us/step - loss: 0.1673
# Epoch 164/800
# 39/39 [==============================] - 0s 562us/step - loss: 0.1240
# Epoch 165/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.2102
# Epoch 166/800
# 39/39 [==============================] - 0s 457us/step - loss: 0.1020
# Epoch 167/800
# 39/39 [==============================] - 0s 438us/step - loss: 0.1184
# Epoch 168/800
# 39/39 [==============================] - 0s 872us/step - loss: 0.1566
# Epoch 169/800
# 39/39 [==============================] - 0s 751us/step - loss: 0.1178
# Epoch 170/800
# 39/39 [==============================] - 0s 667us/step - loss: 0.1257
# Epoch 171/800
# 39/39 [==============================] - 0s 630us/step - loss: 0.0866
# Epoch 172/800
# 39/39 [==============================] - 0s 608us/step - loss: 0.2336
# Epoch 173/800
# 39/39 [==============================] - 0s 658us/step - loss: 0.2545
# Epoch 174/800
# 39/39 [==============================] - 0s 413us/step - loss: 0.0856
# Epoch 175/800
# 39/39 [==============================] - 0s 360us/step - loss: 0.1592
# Epoch 176/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1776
# Epoch 177/800
# 39/39 [==============================] - 0s 457us/step - loss: 0.0807
# Epoch 178/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.2332
# Epoch 179/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1382
# Epoch 180/800
# 39/39 [==============================] - 0s 158us/step - loss: 0.1768
# Epoch 181/800
# 39/39 [==============================] - 0s 471us/step - loss: 0.0876
# Epoch 182/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1581
# Epoch 183/800
# 39/39 [==============================] - 0s 753us/step - loss: 0.1555
# Epoch 184/800
# 39/39 [==============================] - 0s 316us/step - loss: 0.1650
# Epoch 185/800
# 39/39 [==============================] - 0s 276us/step - loss: 0.1781
# Epoch 186/800
# 39/39 [==============================] - 0s 389us/step - loss: 0.1736
# Epoch 187/800
# 39/39 [==============================] - 0s 848us/step - loss: 0.1732
# Epoch 188/800
# 39/39 [==============================] - 0s 446us/step - loss: 0.1046
# Epoch 189/800
# 39/39 [==============================] - 0s 755us/step - loss: 0.1705
# Epoch 190/800
# 39/39 [==============================] - 0s 655us/step - loss: 0.1991
# Epoch 191/800
# 39/39 [==============================] - 0s 351us/step - loss: 0.1847
# Epoch 192/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1968
# Epoch 193/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1102
# Epoch 194/800
# 39/39 [==============================] - 0s 663us/step - loss: 0.1928
# Epoch 195/800
# 39/39 [==============================] - 0s 492us/step - loss: 0.2086
# Epoch 196/800
# 39/39 [==============================] - 0s 253us/step - loss: 0.1028
# Epoch 197/800
# 39/39 [==============================] - 0s 196us/step - loss: 0.1816
# Epoch 198/800
# 39/39 [==============================] - 0s 817us/step - loss: 0.1465
# Epoch 199/800
# 39/39 [==============================] - 0s 694us/step - loss: 0.1267
# Epoch 200/800
# 39/39 [==============================] - 0s 678us/step - loss: 0.0844
# Epoch 201/800
# 39/39 [==============================] - 0s 885us/step - loss: 0.1686
# Epoch 202/800
# 39/39 [==============================] - 0s 499us/step - loss: 0.1013
# Epoch 203/800
# 39/39 [==============================] - 0s 508us/step - loss: 0.2324
# Epoch 204/800
# 39/39 [==============================] - 0s 479us/step - loss: 0.1615
# Epoch 205/800
# 39/39 [==============================] - 0s 471us/step - loss: 0.1124
# Epoch 206/800
# 39/39 [==============================] - 0s 252us/step - loss: 0.1180
# Epoch 207/800
# 39/39 [==============================] - 0s 149us/step - loss: 0.1420
# Epoch 208/800
# 39/39 [==============================] - 0s 466us/step - loss: 0.1369
# Epoch 209/800
# 39/39 [==============================] - 0s 805us/step - loss: 0.1098
# Epoch 210/800
# 39/39 [==============================] - 0s 338us/step - loss: 0.1348
# Epoch 211/800
# 39/39 [==============================] - 0s 397us/step - loss: 0.1578
# Epoch 212/800
# 39/39 [==============================] - 0s 544us/step - loss: 0.1377
# Epoch 213/800
# 39/39 [==============================] - 0s 245us/step - loss: 0.1355
# Epoch 214/800
# 39/39 [==============================] - 0s 773us/step - loss: 0.1026
# Epoch 215/800
# 39/39 [==============================] - 0s 786us/step - loss: 0.0706
# Epoch 216/800
# 39/39 [==============================] - 0s 871us/step - loss: 0.0980
# Epoch 217/800
# 39/39 [==============================] - 0s 344us/step - loss: 0.1999
# Epoch 218/800
# 39/39 [==============================] - 0s 317us/step - loss: 0.1439
# Epoch 219/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1729
# Epoch 220/800
# 39/39 [==============================] - 0s 745us/step - loss: 0.0770
# Epoch 221/800
# 39/39 [==============================] - 0s 388us/step - loss: 0.1230
# Epoch 222/800
# 39/39 [==============================] - 0s 540us/step - loss: 0.0796
# Epoch 223/800
# 39/39 [==============================] - 0s 259us/step - loss: 0.1765
# Epoch 224/800
# 39/39 [==============================] - 0s 249us/step - loss: 0.1011
# Epoch 225/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.2737
# Epoch 226/800
# 39/39 [==============================] - 0s 909us/step - loss: 0.1382
# Epoch 227/800
# 39/39 [==============================] - 0s 391us/step - loss: 0.1519
# Epoch 228/800
# 39/39 [==============================] - 0s 338us/step - loss: 0.0966
# Epoch 229/800
# 39/39 [==============================] - 0s 561us/step - loss: 0.1693
# Epoch 230/800
# 39/39 [==============================] - 0s 303us/step - loss: 0.1065
# Epoch 231/800
# 39/39 [==============================] - 0s 328us/step - loss: 0.1998
# Epoch 232/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0953
# Epoch 233/800
# 39/39 [==============================] - 0s 319us/step - loss: 0.0698
# Epoch 234/800
# 39/39 [==============================] - 0s 358us/step - loss: 0.0995
# Epoch 235/800
# 39/39 [==============================] - 0s 332us/step - loss: 0.1871
# Epoch 236/800
# 39/39 [==============================] - 0s 466us/step - loss: 0.1996
# Epoch 237/800
# 39/39 [==============================] - 0s 920us/step - loss: 0.1544
# Epoch 238/800
# 39/39 [==============================] - 0s 900us/step - loss: 0.1007
# Epoch 239/800
# 39/39 [==============================] - 0s 596us/step - loss: 0.1835
# Epoch 240/800
# 39/39 [==============================] - 0s 762us/step - loss: 0.0615
# Epoch 241/800
# 39/39 [==============================] - 0s 961us/step - loss: 0.1192
# Epoch 242/800
# 39/39 [==============================] - 0s 687us/step - loss: 0.1541
# Epoch 243/800
# 39/39 [==============================] - 0s 220us/step - loss: 0.1535
# Epoch 244/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1406
# Epoch 245/800
# 39/39 [==============================] - 0s 534us/step - loss: 0.1085
# Epoch 246/800
# 39/39 [==============================] - 0s 705us/step - loss: 0.1457
# Epoch 247/800
# 39/39 [==============================] - 0s 924us/step - loss: 0.0612
# Epoch 248/800
# 39/39 [==============================] - 0s 778us/step - loss: 0.1577
# Epoch 249/800
# 39/39 [==============================] - 0s 480us/step - loss: 0.0920
# Epoch 250/800
# 39/39 [==============================] - 0s 488us/step - loss: 0.1388
# Epoch 251/800
# 39/39 [==============================] - 0s 452us/step - loss: 0.0870
# Epoch 252/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1580
# Epoch 253/800
# 39/39 [==============================] - 0s 591us/step - loss: 0.1460
# Epoch 254/800
# 39/39 [==============================] - 0s 273us/step - loss: 0.1479
# Epoch 255/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0831
# Epoch 256/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1404
# Epoch 257/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1095
# Epoch 258/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0695
# Epoch 259/800
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2180
# Epoch 260/800
# 39/39 [==============================] - 0s 399us/step - loss: 0.0739
# Epoch 261/800
# 39/39 [==============================] - 0s 462us/step - loss: 0.1564
# Epoch 262/800
# 39/39 [==============================] - 0s 346us/step - loss: 0.1065
# Epoch 263/800
# 39/39 [==============================] - 0s 548us/step - loss: 0.2470
# Epoch 264/800
# 39/39 [==============================] - 0s 732us/step - loss: 0.0904
# Epoch 265/800
# 39/39 [==============================] - 0s 447us/step - loss: 0.0933
# Epoch 266/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1460
# Epoch 267/800
# 39/39 [==============================] - 0s 412us/step - loss: 0.1239
# Epoch 268/800
# 39/39 [==============================] - 0s 351us/step - loss: 0.1881
# Epoch 269/800
# 39/39 [==============================] - 0s 556us/step - loss: 0.1180
# Epoch 270/800
# 39/39 [==============================] - 0s 749us/step - loss: 0.1351
# Epoch 271/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1466
# Epoch 272/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0806
# Epoch 273/800
# 39/39 [==============================] - 0s 542us/step - loss: 0.1292
# Epoch 274/800
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1059
# Epoch 275/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1610
# Epoch 276/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1328
# Epoch 277/800
# 39/39 [==============================] - 0s 823us/step - loss: 0.1560
# Epoch 278/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0551
# Epoch 279/800
# 39/39 [==============================] - 0s 552us/step - loss: 0.0935
# Epoch 280/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1756
# Epoch 281/800
# 39/39 [==============================] - 0s 356us/step - loss: 0.1174
# Epoch 282/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1298
# Epoch 283/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1662
# Epoch 284/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0614
# Epoch 285/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1062
# Epoch 286/800
# 39/39 [==============================] - 0s 562us/step - loss: 0.1643
# Epoch 287/800
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0843
# Epoch 288/800
# 39/39 [==============================] - 0s 670us/step - loss: 0.2334
# Epoch 289/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1101
# Epoch 290/800
# 39/39 [==============================] - 0s 423us/step - loss: 0.1516
# Epoch 291/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1022
# Epoch 292/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1264
# Epoch 293/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0677
# Epoch 294/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1758
# Epoch 295/800
# 39/39 [==============================] - 0s 348us/step - loss: 0.0754
# Epoch 296/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1002
# Epoch 297/800
# 39/39 [==============================] - 0s 412us/step - loss: 0.1633
# Epoch 298/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0726
# Epoch 299/800
# 39/39 [==============================] - 0s 846us/step - loss: 0.0824
# Epoch 300/800
# 39/39 [==============================] - 0s 307us/step - loss: 0.1691
# Epoch 301/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1415
# Epoch 302/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0805
# Epoch 303/800
# 39/39 [==============================] - 0s 265us/step - loss: 0.1037
# Epoch 304/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1372
# Epoch 305/800
# 39/39 [==============================] - 0s 296us/step - loss: 0.1051
# Epoch 306/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1334
# Epoch 307/800
# 39/39 [==============================] - 0s 432us/step - loss: 0.1311
# Epoch 308/800
# 39/39 [==============================] - 0s 648us/step - loss: 0.1468
# Epoch 309/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1529
# Epoch 310/800
# 39/39 [==============================] - 0s 586us/step - loss: 0.0818
# Epoch 311/800
# 39/39 [==============================] - 0s 978us/step - loss: 0.1262
# Epoch 312/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0748
# Epoch 313/800
# 39/39 [==============================] - 0s 377us/step - loss: 0.0761
# Epoch 314/800
# 39/39 [==============================] - 0s 287us/step - loss: 0.1106
# Epoch 315/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0741
# Epoch 316/800
# 39/39 [==============================] - 0s 817us/step - loss: 0.1528
# Epoch 317/800
# 39/39 [==============================] - 0s 262us/step - loss: 0.1434
# Epoch 318/800
# 39/39 [==============================] - 0s 243us/step - loss: 0.1353
# Epoch 319/800
# 39/39 [==============================] - 0s 151us/step - loss: 0.1547
# Epoch 320/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1181
# Epoch 321/800
# 39/39 [==============================] - 0s 413us/step - loss: 0.0670
# Epoch 322/800
# 39/39 [==============================] - 0s 821us/step - loss: 0.1372
# Epoch 323/800
# 39/39 [==============================] - 0s 225us/step - loss: 0.0629
# Epoch 324/800
# 39/39 [==============================] - 0s 343us/step - loss: 0.1754
# Epoch 325/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0471
# Epoch 326/800
# 39/39 [==============================] - 0s 529us/step - loss: 0.1241
# Epoch 327/800
# 39/39 [==============================] - 0s 293us/step - loss: 0.0818
# Epoch 328/800
# 39/39 [==============================] - 0s 235us/step - loss: 0.1184
# Epoch 329/800
# 39/39 [==============================] - 0s 514us/step - loss: 0.0915
# Epoch 330/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1571
# Epoch 331/800
# 39/39 [==============================] - 0s 388us/step - loss: 0.0856
# Epoch 332/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0851
# Epoch 333/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0945
# Epoch 334/800
# 39/39 [==============================] - 0s 967us/step - loss: 0.1587
# Epoch 335/800
# 39/39 [==============================] - 0s 488us/step - loss: 0.0717
# Epoch 336/800
# 39/39 [==============================] - 0s 469us/step - loss: 0.1526
# Epoch 337/800
# 39/39 [==============================] - 0s 573us/step - loss: 0.0688
# Epoch 338/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0964
# Epoch 339/800
# 39/39 [==============================] - 0s 842us/step - loss: 0.0767
# Epoch 340/800
# 39/39 [==============================] - 0s 196us/step - loss: 0.1412
# Epoch 341/800
# 39/39 [==============================] - 0s 216us/step - loss: 0.0578
# Epoch 342/800
# 39/39 [==============================] - 0s 319us/step - loss: 0.0787
# Epoch 343/800
# 39/39 [==============================] - 0s 241us/step - loss: 0.1624
# Epoch 344/800
# 39/39 [==============================] - 0s 708us/step - loss: 0.2925
# Epoch 345/800
# 39/39 [==============================] - 0s 396us/step - loss: 0.1087
# Epoch 346/800
# 39/39 [==============================] - 0s 850us/step - loss: 0.0994
# Epoch 347/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1043
# Epoch 348/800
# 39/39 [==============================] - 0s 543us/step - loss: 0.1334
# Epoch 349/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0860
# Epoch 350/800
# 39/39 [==============================] - 0s 785us/step - loss: 0.1211
# Epoch 351/800
# 39/39 [==============================] - 0s 244us/step - loss: 0.1289
# Epoch 352/800
# 39/39 [==============================] - 0s 988us/step - loss: 0.1442
# Epoch 353/800
# 39/39 [==============================] - 0s 963us/step - loss: 0.1219
# Epoch 354/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1183
# Epoch 355/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0612
# Epoch 356/800
# 39/39 [==============================] - 0s 351us/step - loss: 0.1689
# Epoch 357/800
# 39/39 [==============================] - 0s 254us/step - loss: 0.0668
# Epoch 358/800
# 39/39 [==============================] - 0s 460us/step - loss: 0.2116
# Epoch 359/800
# 39/39 [==============================] - 0s 398us/step - loss: 0.0857
# Epoch 360/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.2276
# Epoch 361/800
# 39/39 [==============================] - 0s 534us/step - loss: 0.0627
# Epoch 362/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1200
# Epoch 363/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0883
# Epoch 364/800
# 39/39 [==============================] - 0s 318us/step - loss: 0.1166
# Epoch 365/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0670
# Epoch 366/800
# 39/39 [==============================] - 0s 453us/step - loss: 0.1473
# Epoch 367/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0555
# Epoch 368/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1646
# Epoch 369/800
# 39/39 [==============================] - 0s 666us/step - loss: 0.1504
# Epoch 370/800
# 39/39 [==============================] - 0s 556us/step - loss: 0.0987
# Epoch 371/800
# 39/39 [==============================] - 0s 898us/step - loss: 0.1426
# Epoch 372/800
# 39/39 [==============================] - 0s 759us/step - loss: 0.0770
# Epoch 373/800
# 39/39 [==============================] - 0s 938us/step - loss: 0.1630
# Epoch 374/800
# 39/39 [==============================] - 0s 400us/step - loss: 0.0603
# Epoch 375/800
# 39/39 [==============================] - 0s 216us/step - loss: 0.1400
# Epoch 376/800
# 39/39 [==============================] - 0s 240us/step - loss: 0.0778
# Epoch 377/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0806
# Epoch 378/800
# 39/39 [==============================] - 0s 621us/step - loss: 0.0569
# Epoch 379/800
# 39/39 [==============================] - 0s 300us/step - loss: 0.0951
# Epoch 380/800
# 39/39 [==============================] - 0s 749us/step - loss: 0.1333
# Epoch 381/800
# 39/39 [==============================] - 0s 564us/step - loss: 0.0586
# Epoch 382/800
# 39/39 [==============================] - 0s 429us/step - loss: 0.1372
# Epoch 383/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1391
# Epoch 384/800
# 39/39 [==============================] - 0s 519us/step - loss: 0.1671
# Epoch 385/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1313
# Epoch 386/800
# 39/39 [==============================] - 0s 430us/step - loss: 0.0907
# Epoch 387/800
# 39/39 [==============================] - 0s 221us/step - loss: 0.0831
# Epoch 388/800
# 39/39 [==============================] - 0s 417us/step - loss: 0.2027
# Epoch 389/800
# 39/39 [==============================] - 0s 333us/step - loss: 0.1049
# Epoch 390/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0687
# Epoch 391/800
# 39/39 [==============================] - 0s 690us/step - loss: 0.1316
# Epoch 392/800
# 39/39 [==============================] - 0s 331us/step - loss: 0.0674
# Epoch 393/800
# 39/39 [==============================] - 0s 329us/step - loss: 0.1236
# Epoch 394/800
# 39/39 [==============================] - 0s 221us/step - loss: 0.0910
# Epoch 395/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1269
# Epoch 396/800
# 39/39 [==============================] - 0s 240us/step - loss: 0.0777
# Epoch 397/800
# 39/39 [==============================] - 0s 671us/step - loss: 0.1256
# Epoch 398/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0775
# Epoch 399/800
# 39/39 [==============================] - 0s 461us/step - loss: 0.1631
# Epoch 400/800
# 39/39 [==============================] - 0s 819us/step - loss: 0.0899
# Epoch 401/800
# 39/39 [==============================] - 0s 988us/step - loss: 0.0802
# Epoch 402/800
# 39/39 [==============================] - 0s 565us/step - loss: 0.0691
# Epoch 403/800
# 39/39 [==============================] - 0s 997us/step - loss: 0.0671
# Epoch 404/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0548
# Epoch 405/800
# 39/39 [==============================] - 0s 370us/step - loss: 0.2472
# Epoch 406/800
# 39/39 [==============================] - 0s 305us/step - loss: 0.0736
# Epoch 407/800
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0663
# Epoch 408/800
# 39/39 [==============================] - 0s 323us/step - loss: 0.0938
# Epoch 409/800
# 39/39 [==============================] - 0s 293us/step - loss: 0.1503
# Epoch 410/800
# 39/39 [==============================] - 0s 247us/step - loss: 0.1152
# Epoch 411/800
# 39/39 [==============================] - 0s 496us/step - loss: 0.1527
# Epoch 412/800
# 39/39 [==============================] - 0s 441us/step - loss: 0.1007
# Epoch 413/800
# 39/39 [==============================] - 0s 272us/step - loss: 0.1185
# Epoch 414/800
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0803
# Epoch 415/800
# 39/39 [==============================] - 0s 373us/step - loss: 0.1018
# Restoring model weights from the end of the best epoch
# Epoch 00415: early stopping
# best epoch =  325
# smallest loss = 0.04705660446332051

# %% [markdown]
# ## (e) Training Set

# %%
y_predictions_df = pd.DataFrame(model.predict(x_train), columns=['mdot'])
y_predictions_df[:5]
# Out:
#        mdot
# 0  0.838984
# 1  0.521625
# 2  0.643208
# 3  2.472154
# 4  1.541645

# %%
y_recorded_df = y_train
y_recorded_df[:5]
# Out:
#        mdot
# 0  0.771722
# 1  0.503400
# 2  0.692175
# 3  2.257960
# 4  1.243497

# %% [markdown]
# ### MAE

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_recorded_df['mdot'], y_predictions_df['mdot'])
print(f'MAE: {mae}')
# Out:
# MAE: 0.11038735682398816

# %% [markdown]
# ### Log-log Plot

# %%
logLogPlotter(y_recorded_df['mdot'], y_predictions_df['mdot'], -0.5, 1.5, -0.5, 1.5, 'mdot', 'mdot', '')

# %% [markdown]
# ## (f) Validation Set

# %%
y_predictions_df = pd.DataFrame(model.predict(x_validate), columns=['mdot'])
y_predictions_df[:5]
# Out:
#        mdot
# 0  1.152565
# 1  1.352978
# 2  1.373867
# 3  1.412574
# 4  0.722325

# %%
y_recorded_df = y_validate
y_recorded_df[:5]
# Out:
#        mdot
# 0  1.051808
# 1  1.147868
# 2  1.245548
# 3  1.254182
# 4  0.664544

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_recorded_df['mdot'], y_predictions_df['mdot'])
print(f'MAE: {mae}')
# Out:
# MAE: 0.16150012319651827

# %%
logLogPlotter(y_recorded_df['mdot'], y_predictions_df['mdot'], -0.5, 1.5, -0.5, 1.5, 'mdot', 'mdot', '')
